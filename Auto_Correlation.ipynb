# %%
run utils.ipynb
# Out:
# <style>
# .text_cell_render {
#     line-height: 2.5;
# }
# .text_cell_render.rendered_html hr {
#     border-top: 1px solid #bbb;
# }
# </style>

# %%
data = np.random.normal(size=500)

# %%
plt.plot(data)
